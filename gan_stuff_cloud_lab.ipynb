# %%
# !git config --global user.email 'rwebstr@gmail.com'
# !git config --global user.name 'ryanwebster90'

from getpass import getpass
password = getpass('Password:')
# !git clone https://ryanwebster90:$password@github.com/ryanwebster90/gan-stuff.git
# %cd gan-stuff
# Out:
# Password: ············
# Cloning into 'gan-stuff'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 8 (delta 0), reused 5 (delta 0), pack-reused 3
# Unpacking objects: 100% (8/8), done.
# /workspace/gan-stuff

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1MAl3-sTelBXi_gzQKMFY2udDaioecvjc' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1MAl3-sTelBXi_gzQKMFY2udDaioecvjc" -O ffhq_256.tar.gz && rm -rf /tmp/cookies.txt
# Out:
# --2020-10-05 03:55:47--  https://docs.google.com/uc?export=download&confirm=RDzv&id=1MAl3-sTelBXi_gzQKMFY2udDaioecvjc
# Resolving docs.google.com... 216.58.207.238, 2a00:1450:400f:809::200e
# Connecting to docs.google.com|216.58.207.238|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-1s-docs.googleusercontent.com/docs/securesc/e3ijcje1gpl7iqm41hob75hlub6408fv/h1iosm33qnahsdtngmofmpaan7supmf3/1601870100000/12985120183340644999/15061202718874441128Z/1MAl3-sTelBXi_gzQKMFY2udDaioecvjc?e=download [following]
# --2020-10-05 03:55:48--  https://doc-0k-1s-docs.googleusercontent.com/docs/securesc/e3ijcje1gpl7iqm41hob75hlub6408fv/h1iosm33qnahsdtngmofmpaan7supmf3/1601870100000/12985120183340644999/15061202718874441128Z/1MAl3-sTelBXi_gzQKMFY2udDaioecvjc?e=download
# Resolving doc-0k-1s-docs.googleusercontent.com... 216.58.211.129, 2a00:1450:400f:808::2001
# ...

# %%
# !tar -xf ffhq_256.tar.gz

# %%
# !mkdir ffhq_256
# !mv ffhq_256x256 ffhq_256
# Out:
# mkdir: cannot create directory ‘ffhq_256’: File exists
# mv: cannot stat 'ffhq_256x256': No such file or directory

# %%
# !python train_gan.py --config ffhq_256.yaml
# Out:
# train_gan.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)
# Random Seed:  6885
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# [0/100][0/8750] Loss_D: 1.6955 Loss_G: 8.1413 GP(D)0.0000
# [0/100][1/8750] Loss_D: 52.4491 Loss_G: 2.3649 GP(D)0.0000
# [0/100][2/8750] Loss_D: 14.5789 Loss_G: 0.3566 GP(D)0.0000
# [0/100][3/8750] Loss_D: 6.0129 Loss_G: 3.8859 GP(D)0.0000
# [0/100][4/8750] Loss_D: 5.5504 Loss_G: 1.2953 GP(D)0.0000
# [0/100][5/8750] Loss_D: 7.7019 Loss_G: 2.3156 GP(D)0.0000
# [0/100][6/8750] Loss_D: 13.8404 Loss_G: 2.7663 GP(D)0.0000
# [0/100][7/8750] Loss_D: 9.4157 Loss_G: 1.6316 GP(D)0.0000
# [0/100][8/8750] Loss_D: 10.0294 Loss_G: 1.8858 GP(D)0.0000
# ...
